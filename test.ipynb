# %%
import xarm_lite6_mjlab
import mujoco

# %%
model = spec.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = spec.compile()
#
# ValueError: Error: Error opening file '../mujoco_menagerie/ufactory_lite6/assets/visual/gripper_lite_left_finger_internal.stl'

# %%
spec.meshdir
# Out:
# '../mujoco_menagerie/ufactory_lite6/assets/'
